# %%
#List of temperatures measured at Tribhuwan International Airpot

temperatures = [
    8.2, 17.4, 14.1, 7.9, 18.0, 13.5, 9.0, 17.8, 13.0, 8.5,
    16.5, 12.9, 7.7, 17.2, 13.3, 8.4, 16.7, 14.0, 9.5, 18.3,
    13.4, 8.1, 17.9, 14.2, 7.6, 17.0, 12.8, 8.0, 16.8, 13.7,
    7.8, 17.5, 13.6, 8.7, 17.1, 13.8, 9.2, 18.1, 13.9, 8.3,
    16.4, 12.7, 8.9, 18.2, 13.1, 7.8, 16.6, 12.5
]

#Initialize empty lists for classifications
cold = []
mild = []
comfortable = []

#Iterate through the temperature list and classify

for temp in temperatures:
  if temp < 10:
    cold.append(temp)
  elif 10 <= temp < 15:
    mild.append(temp)
  elif 15 <= temp <= 20:
    comfortable.append(temp)

#Print results to verify the classificatons
print("Cold temperatures (< 10 degree C) is: ", cold)
print("Mild temperatures  (10 degree C between 15 degree C) is: ", mild)
print("Comfortable temperatures (15 degree C between 20 degree C) is: ", comfortable)
# Out:
# Cold temperatures (< 10 degree C) is:  [8.2, 7.9, 9.0, 8.5, 7.7, 8.4, 9.5, 8.1, 7.6, 8.0, 7.8, 8.7, 9.2, 8.3, 8.9, 7.8]
# Mild temperatures  (10 degree C between 15 degree C) is:  [14.1, 13.5, 13.0, 12.9, 13.3, 14.0, 13.4, 14.2, 12.8, 13.7, 13.6, 13.8, 13.9, 12.7, 13.1, 12.5]
# Comfortable temperatures (15 degree C between 20 degree C) is:  [17.4, 18.0, 17.8, 16.5, 17.2, 16.7, 18.3, 17.9, 17.0, 16.8, 17.5, 17.1, 18.1, 16.4, 18.2, 16.6]

# %%
# Count the number of times it was mild
mild_count = len(mild)
print("Number of times it was mild:", mild_count)
# Out:
# Number of times it was mild: 16

# %%
# Count the number of times it was comfortable
comfortable_count = len(comfortable)
print("Number of times it was comfortable:", comfortable_count)
# Out:
# Number of times it was comfortable: 16

# %%
# Count the number of times it was cold
cold_count = len(cold)
print("Number of times it was cold:", cold_count)
# Out:
# Number of times it was cold: 16

# %%
#List of temperatures measured at Tribhuwan International Airpot (in Celsius)

temperatures = [
    8.2, 17.4, 14.1, 7.9, 18.0, 13.5, 9.0, 17.8, 13.0, 8.5,
    16.5, 12.9, 7.7, 17.2, 13.3, 8.4, 16.7, 14.0, 9.5, 18.3,
    13.4, 8.1, 17.9, 14.2, 7.6, 17.0, 12.8, 8.0, 16.8, 13.7,
    7.8, 17.5, 13.6, 8.7, 17.1, 13.8, 9.2, 18.1, 13.9, 8.3,
    16.4, 12.7, 8.9, 18.2, 13.1, 7.8, 16.6, 12.5
]

# Initialize an empty list to store Fahrenheit values
temperatures_fahrenheit = []

# Iterate over the Celsius temperatures and convert each to Fahrenheit
for temp in temperatures:
    fahrenheit = (temp * 9 / 5) + 32  # Apply the formula
    temperatures_fahrenheit.append(fahrenheit)  # Add the result to the new list

# Print the converted Fahrenheit values
print("Temperatures in Fahrenheit:", temperatures_fahrenheit)
# Out:
# Temperatures in Fahrenheit: [46.76, 63.32, 57.379999999999995, 46.22, 64.4, 56.3, 48.2, 64.04, 55.4, 47.3, 61.7, 55.22, 45.86, 62.959999999999994, 55.94, 47.120000000000005, 62.059999999999995, 57.2, 49.1, 64.94, 56.120000000000005, 46.58, 64.22, 57.56, 45.68, 62.6, 55.04, 46.4, 62.24, 56.66, 46.04, 63.5, 56.48, 47.66, 62.78, 56.84, 48.56, 64.58, 57.02, 46.94, 61.519999999999996, 54.86, 48.02, 64.75999999999999, 55.58, 46.04, 61.88, 54.5]

# %%
# List of temperatures measured at Tribhuwan International Airport (in Celsius)
temperatures = [
    8.2, 17.4, 14.1, 7.9, 18.0, 13.5, 9.0, 17.8, 13.0, 8.5,
    16.5, 12.9, 7.7, 17.2, 13.3, 8.4, 16.7, 14.0, 9.5, 18.3,
    13.4, 8.1, 17.9, 14.2, 7.6, 17.0, 12.8, 8.0, 16.8, 13.7,
    7.8, 17.5, 13.6, 8.7, 17.1, 13.8, 9.2, 18.1, 13.9, 8.3,
    16.4, 12.7, 8.9, 18.2, 13.1, 7.8, 16.6, 12.5
]

# Initialize empty lists for night, evening, and day temperatures
night_temperatures = []
evening_temperatures = []
day_temperatures = []

# Classify temperatures based on their position
for i in range(len(temperatures)):
    if i % 3 == 0:  # Night readings (index 0, 3, 6, ...)
        night_temperatures.append(temperatures[i])
    elif i % 3 == 1:  # Evening readings (index 1, 4, 7, ...)
        evening_temperatures.append(temperatures[i])
    elif i % 3 == 2:  # Day readings (index 2, 5, 8, ...)
        day_temperatures.append(temperatures[i])

# Print classified temperatures
print("Night temperatures:", night_temperatures)
print("Evening temperatures:", evening_temperatures)
print("Day temperatures:", day_temperatures)

# Calculate the average day-time temperature
average_day_temperature = sum(day_temperatures) / len(day_temperatures)
print(f"Average day-time temperature: {average_day_temperature:.2f}°C")

import matplotlib.pyplot as plt

# Generate day indices (1 to the number of days)
days = list(range(1, len(day_temperatures) + 1))

# Plot "day vs. temperature"
plt.figure(figsize=(10, 5))
plt.plot(days, day_temperatures, marker='o', label='Day Temperatures')
plt.title("Day vs. Temperature")
plt.xlabel("Day")
plt.ylabel("Temperature (°C)")
plt.xticks(days)  # Show each day as a tick
plt.grid()
plt.legend()
plt.show()
# Out:
# Night temperatures: [8.2, 7.9, 9.0, 8.5, 7.7, 8.4, 9.5, 8.1, 7.6, 8.0, 7.8, 8.7, 9.2, 8.3, 8.9, 7.8]
# Evening temperatures: [17.4, 18.0, 17.8, 16.5, 17.2, 16.7, 18.3, 17.9, 17.0, 16.8, 17.5, 17.1, 18.1, 16.4, 18.2, 16.6]
# Day temperatures: [14.1, 13.5, 13.0, 12.9, 13.3, 14.0, 13.4, 14.2, 12.8, 13.7, 13.6, 13.8, 13.9, 12.7, 13.1, 12.5]
# Average day-time temperature: 13.41°C

# %%
def sum_nested_list(nested_list):
    """
    Calculate the sum of all numbers in a nested list.

    This function takes a list that may contain integers and other nested lists.
    It recursively traverses the list and sums all the integers, no matter how deeply
    nested they are.

    Args:
        nested_list (list): A list that may contain integers or other lists of integers.

    Returns:
        int: The total sum of all integers in the nested list, including those in sublists.

    Example:
        >>> sum_nested_list([1, [2, [3, 4], 5], 6, [7, 8]])
        36
        >>> sum_nested_list([1, [2, 3], [4, [5]]])
        15
    """
    total = 0  # Initialize the total sum

    # Iterate over each element in the nested list
    for element in nested_list:
        if isinstance(element, list):  # Check if the element is a list
            total += sum_nested_list(element)  # Recursively sum the nested list
        else:
            total += element  # Add the number to the total

    return total


# Test the function with a sample nested list
nested_list = [1, [2, [3, 4], 5], 6, [7, 8]]
result = sum_nested_list(nested_list)
print("The total sum of all numbers in the nested list is:", result)
# Out:
# The total sum of all numbers in the nested list is: 36

# %%
def generate_permutations(s):
    """
    Generate all unique permutations of a given string.

    Args:
        s (str): The input string.

    Returns:
        list: A list containing all unique permutations of the input string.

    Example:
        >>> generate_permutations("abc")
        ['abc', 'acb', 'bac', 'bca', 'cab', 'cba']
        >>> generate_permutations("aab")
        ['aab', 'aba', 'baa']
    """
    # Base case: If the string has only one character, return it as the only permutation
    if len(s) == 1:
        return [s]

    # Use a set to store unique permutations
    permutations = set()

    # Recursively generate permutations by fixing one character at a time
    for i, char in enumerate(s):
        # Exclude the current character and find permutations of the remaining substring
        remaining = s[:i] + s[i+1:]
        for perm in generate_permutations(remaining):
            # Add the current character to each permutation of the substring
            permutations.add(char + perm)

    # Convert the set to a sorted list to ensure a consistent order
    return sorted(permutations)

# Test cases
print(generate_permutations("abc"))  # Should return ['abc', 'acb', 'bac', 'bca', 'cab', 'cba']
print(generate_permutations("aab"))  # Should return ['aab', 'aba', 'baa']
# Out:
# ['abc', 'acb', 'bac', 'bca', 'cab', 'cba']
# ['aab', 'aba', 'baa']

# %%
    def calculate_directory_size(directory):
        """
        Recursively calculates the total size of a directory, including all nested files and subdirectories.
    
        Args:
            directory (dict): A dictionary representing the directory structure, where:
                - Keys are file names or directory names.
                - Values are file sizes (for files) or another dictionary (for subdirectories).
    
        Returns:
            int: The total size of the directory in KB.
    
        Example:
            directory_structure = {
                "file1.txt": 200,
                "file2.txt": 300,
                "subdir1": {
                    "file3.txt": 400,
                    "file4.txt": 100
                },
                "subdir2": {
                    "subsubdir1": {
                        "file5.txt": 250
                    },
                    "file6.txt": 150
                }
            }
            >>> calculate_directory_size(directory_structure)
            1400
        """
        total_size = 0  # Initialize total size
    
        for key, value in directory.items():
            if isinstance(value, dict):  # If the value is a subdirectory
                total_size += calculate_directory_size(value)  # Recursively calculate its size
            else:  # If the value is a file size
                total_size += value
    
        return total_size
    
    # Sample directory structure
    directory_structure = {
        "file1.txt": 200,
        "file2.txt": 300,
        "subdir1": {
            "file3.txt": 400,
            "file4.txt": 100
        },
        "subdir2": {
            "subsubdir1": {
                "file5.txt": 250
            },
            "file6.txt": 150
        }
    }
    
    # Calculate and print the total size of the sample directory structure
    total_size = calculate_directory_size(directory_structure)
    print("The total size of the directory is:", total_size, "KB")
# Out:
# The total size of the directory is: 1400 KB

# %%
def min_coins(coins, amount):
    """
    Finds the minimum number of coins needed to make up a given amount using dynamic programming.

    Args:
        coins (list of int): A list of coin denominations available for making change.
        amount (int): The target amount for which we need to find the minimum number of coins.

    Returns:
        int: The minimum number of coins required to make the given amount.
        If it is not possible to make the amount with the given coins, returns -1.

    Example:
        >>> min_coins([1, 2, 5], 11)
        3
        >>> min_coins([2], 3)
        -1
    """
    # Initialize DP array with a value larger than the possible number of coins
    dp = [float('inf')] * (amount + 1)  # Use inf as the initial value to represent unachievable amounts
    dp[0] = 0  # No coins are needed to make 0 amount

    # Iterate through each coin
    for coin in coins:
        # Update the dp array for each amount that can be reached using the current coin
        for i in range(coin, amount + 1):
            dp[i] = min(dp[i], dp[i - coin] + 1)

    # If the value for dp[amount] is still infinity, it means it's not possible to make the amount
    return dp[amount] if dp[amount] != float('inf') else -1

# Test cases
print(min_coins([1, 2, 5], 11))  # Should return 3 (using [5, 5, 1])
print(min_coins([2], 3))  # Should return -1 (not possible)
# Out:
# 3
# -1

# %%
def longest_common_subsequence(s1, s2):
    """
    Finds the length of the longest common subsequence (LCS) between two strings using dynamic programming.

    Args:
        s1 (str): The first string.
        s2 (str): The second string.

    Returns:
        int: The length of the longest common subsequence.

    Example:
        >>> longest_common_subsequence("abcde", "ace")
        3
        >>> longest_common_subsequence("abc", "def")
        0
    """
    # Initialize a 2D DP table with 0s, where dp[i][j] represents the LCS of s1[0...i-1] and s2[0...j-1]
    dp = [[0] * (len(s2) + 1) for _ in range(len(s1) + 1)]

    # Fill the DP table
    for i in range(1, len(s1) + 1):
        for j in range(1, len(s2) + 1):
            if s1[i - 1] == s2[j - 1]:  # If characters match
                dp[i][j] = dp[i - 1][j - 1] + 1
            else:  # If characters don't match, take the maximum from the left or top cell
                dp[i][j] = max(dp[i - 1][j], dp[i][j - 1])

    # The value at dp[len(s1)][len(s2)] will hold the length of the LCS
    return dp[len(s1)][len(s2)]

# Test cases
print(longest_common_subsequence("abcde", "ace"))  # Should return 3 (LCS is "ace")
print(longest_common_subsequence("abc", "def"))    # Should return 0 (No common subsequence)
# Out:
# 3
# 0

# %%
def knapsack(weights, values, capacity):
    """
    Solves the 0/1 Knapsack problem using dynamic programming to maximize the value
    of items that can be carried without exceeding the weight capacity.

    Args:
        weights (list of int): A list representing the weights of items.
        values (list of int): A list representing the values of items.
        capacity (int): The maximum weight capacity of the knapsack.

    Returns:
        int: The maximum value that can be achieved within the given weight capacity.

    Example:
        >>> knapsack([1, 2, 3], [10, 20, 30], 5)
        50
    """
    n = len(weights)  # Number of items
    # Initialize a DP table with all values as 0 (0 weight capacity, 0 items)
    dp = [[0] * (capacity + 1) for _ in range(n + 1)]

    # Fill the DP table
    for i in range(1, n + 1):  # Loop through each item
        for w in range(1, capacity + 1):  # Loop through each weight capacity
            if weights[i - 1] <= w:  # If the item can fit into the current capacity
                dp[i][w] = max(dp[i - 1][w], dp[i - 1][w - weights[i - 1]] + values[i - 1])
            else:
                dp[i][w] = dp[i - 1][w]  # If the item can't fit, take the previous value

    # The maximum value will be in dp[n][capacity]
    return dp[n][capacity]

# Test the function
weights = [1, 2, 3]
values = [10, 20, 30]
capacity = 5
print(knapsack(weights, values, capacity))  # Should return 50
# Out:
# 50
